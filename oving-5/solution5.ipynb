# %%
# Task 1, 2, 3
import pandas as pd
from sklearn import datasets

df = pd.read_csv('./agaricus-lepiota.data')
df
# Out:
#      edibility cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 0            p         x           s         n        t    p               f
# 1            e         x           s         y        t    a               f
# 2            e         b           s         w        t    l               f
# 3            p         x           y         w        t    p               f
# 4            e         x           s         g        f    n               f
# ...        ...       ...         ...       ...      ...  ...             ...
# 8119         e         k           s         n        f    n               a
# 8120         e         x           s         n        f    n               a
# 8121         e         f           s         n        f    n               a
# 8122         p         k           y         n        f    y               f
# 8123         e         x           s         n        f    n               a
#
# ...

# %%
# Task 4/5
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import LabelEncoder

# First we must convert the data into ordinal data
label_encoder = LabelEncoder()

df.astype('category')
for column in df.columns:
    df[column] = label_encoder.fit_transform(df[column])

# Remove veil-type from the dataset, as it only has one unique value
if "veil-type" in df.columns: df = df.drop(["veil-type"], axis=1) 

df.head()
# Out:
#    edibility  cap-shape  cap-surface  cap-color  bruises?  odor  \
# 0          1          5            2          4         1     6
# 1          0          5            2          9         1     0
# 2          0          0            2          8         1     3
# 3          1          5            3          8         1     6
# 4          0          5            2          3         0     5
#
#    gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                1             0          1           4  ...
# 1                1             0          0           4  ...
# 2                1             0          0           5  ...
# 3                1             0          1           5  ...
# 4                1             1          0           4  ...
#
#    stalk-surface-above-ring  stalk-surface-below-ring  stalk-color-above-ring  \
# 0                         2                         2                       7
# ...

# %%
# Show distributions
plt.figure()
df.hist(color='k', alpha=0.5, bins=10, figsize=(12, 12))
# Out:
# array([[<AxesSubplot:title={'center':'edibility'}>,
#         <AxesSubplot:title={'center':'cap-shape'}>,
#         <AxesSubplot:title={'center':'cap-surface'}>,
#         <AxesSubplot:title={'center':'cap-color'}>,
#         <AxesSubplot:title={'center':'bruises?'}>],
#        [<AxesSubplot:title={'center':'odor'}>,
#         <AxesSubplot:title={'center':'gill-attachment'}>,
#         <AxesSubplot:title={'center':'gill-spacing'}>,
#         <AxesSubplot:title={'center':'gill-size'}>,
#         <AxesSubplot:title={'center':'gill-color'}>],
#        [<AxesSubplot:title={'center':'stalk-shape'}>,
#         <AxesSubplot:title={'center':'stalk-root'}>,
#         <AxesSubplot:title={'center':'stalk-surface-above-ring'}>,
#         <AxesSubplot:title={'center':'stalk-surface-below-ring'}>,
#         <AxesSubplot:title={'center':'stalk-color-above-ring'}>],
#        [<AxesSubplot:title={'center':'stalk-color-below-ring'}>,
#         <AxesSubplot:title={'center':'veil-color'}>,
# ...

# %%
scatter_matrix(df, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='edibility', ylabel='edibility'>,
#         <AxesSubplot:xlabel='cap-shape', ylabel='edibility'>,
#         <AxesSubplot:xlabel='cap-surface', ylabel='edibility'>,
#         <AxesSubplot:xlabel='cap-color', ylabel='edibility'>,
#         <AxesSubplot:xlabel='bruises?', ylabel='edibility'>,
#         <AxesSubplot:xlabel='odor', ylabel='edibility'>,
#         <AxesSubplot:xlabel='gill-attachment', ylabel='edibility'>,
#         <AxesSubplot:xlabel='gill-spacing', ylabel='edibility'>,
#         <AxesSubplot:xlabel='gill-size', ylabel='edibility'>,
#         <AxesSubplot:xlabel='gill-color', ylabel='edibility'>,
#         <AxesSubplot:xlabel='stalk-shape', ylabel='edibility'>,
#         <AxesSubplot:xlabel='stalk-root', ylabel='edibility'>,
#         <AxesSubplot:xlabel='stalk-surface-above-ring', ylabel='edibility'>,
#         <AxesSubplot:xlabel='stalk-surface-below-ring', ylabel='edibility'>,
# ...

# %%
# Task 6
import numpy as np
df = pd.read_csv('./agaricus-lepiota.data')
df = pd.get_dummies(df)
dummies = pd.get_dummies(df).rename(columns=lambda x: 'Category_' + str(x))
df = pd.concat([df, dummies], axis=1)
print(df)


indices = np.argsort(df.columns)

plt.spy(df, markersize=0.1)
fig = plt.gcf()
fig.set_size_inches(200, 200)
plt.plot()
plt.show()
# Out:
#       edibility_e  edibility_p  cap-shape_b  cap-shape_c  cap-shape_f  \
# 0               0            1            0            0            0
# 1               1            0            0            0            0
# 2               1            0            1            0            0
# 3               0            1            0            0            0
# 4               1            0            0            0            0
# ...           ...          ...          ...          ...          ...
# 8119            1            0            0            0            0
# 8120            1            0            0            0            0
# 8121            1            0            0            0            1
# 8122            0            1            0            0            0
# 8123            1            0            0            0            0
#
#       cap-shape_k  cap-shape_s  cap-shape_x  cap-surface_f  cap-surface_g  \
# ...
